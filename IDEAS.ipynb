# %% [markdown]
# ## Introduction

# %% [markdown]
# Goals of this section:
#
# 1. Explain the game and its goal
# 2. Teach the user what the OpenBB Platform is all about
# 3. Speak about the main strengths of the Platform ([multiple choice] all answers are correct)
# 4. Introduce them to the topic we’ll be exploring

# %% [markdown]
# Requirements:
#
# 1. The user should have an account on the OpenBB Hub
# 2. The user should have a FinancialModelingPrep API key set up in the Hub

# %% [markdown]
# We need to have different types of questions for the json schema:
#
# 1. Multiple choice
# 2. Single choice
# 3. Text
# 4. Code
# 5. Just a paragraph of text on which they click Next to continue

# %% [markdown]
# ### Introduction Q1

# %% [markdown]
# The OpenBB Platform is:
#    1. Modular
#    2. Scalable
#    3. Secure
#    4. Open Source

# %% [markdown]
# The topic we'll be exploring is performing investment research on Netlifx (NFLX) and its peers for a pair trading strategy

# %% [markdown]
# ### Introduction Q2

# %% [markdown]
# Pairs trading is a strategy where:
# 1. a trader buys one asset while shorting another. The main premise of the trade is that when the two pairs diverge, they will likely converge again resulting in profit for the trader.
# 2. a trader buys one asset while shorting another. The main premise of the trade is that when the two pairs diverge, they will likely diverge even further resulting in profit for the trader.
# 3. a trader buys both assets and holds them for a long time.
# 4. a trader buys low and sells high.

# %% [markdown]
# ### Introduction Q3

# %% [markdown]
# For a Pairs trading strategy to work the best, the two assets should be:
#
# 1. highly correlated
# 2. highly uncorrelated
# 3. correlated and cointegrated
# 4. correlated with the S&P 500

# %% [markdown]
# ## Setup

# %% [markdown]
# Goals of this section:
#
# 1. Install the Platform [multiple choice]
# 2. Point them to the Hub to set up their API keys (say which keys they need)
# 3. Log in to the Hub

# %% [markdown]
# ### Setup Q1

# %% [markdown]
# To install the OpenBB Platform you need to:
#
# 1. Install Docker and run: `docker run -p 8888:8888 openbb/platform`
# 2. Run `pip install openbb-platform`
# 3. Turn on your computer and wait for the Platform to install itself
# 4. Run `pip install openbb`

# %% [markdown]
# ### Setup Q2

# %% [markdown]
# To import the OpenBB Platform you need to:
# 1. `from openbb-platform import platform`
# 2. `import openbb-platform`
# 3. `from openbb import platform`
# 4. `from openbb import obb`

# %%
from openbb import obb

# %% [markdown]
# ### Setup Q3

# %% [markdown]
# To connect to the Hub you need to run:
# 1. `obb.connect`
# 2. `obb.account.login(email='email', password='password')`
# 3. `obb.account.connect(email='email', password='password')`
# 4. `obb.login(email='email', password='password')`

# %%
# obb.account.login(email='email', password='password')

# %% [markdown]
# ## Exploration

# %% [markdown]
# Explore NFLX and its financials to justify why we want to trade its peers against it
#
# Get the balance sheet [multiple choice]
#
# Get the income statement X value [input]
#
# Get the cash flow statement -> See if X is larger or smaller than Y [true/false]
#
# Find the Peers (suggest that the user explores them too)
#
# Navigate to the right menu [multiple choice]
#
# Ask the user to obtain the X value for Y year and Z quarter of ROKU

# %% [markdown]
# ### Exploration Q1

# %% [markdown]
# To analyze the NFLX balance sheet we need to access which namespace:
# 1. `obb.financials.balance_sheet`
# 2. `obb.fundamental.balance`
# 3. `obb.equity.fundamental.balance`
# 4. `obb.balance_sheet`

# %%
obb.equity.fundamental.balance("NFLX")
# Out:
# OBBject
#
# id: 06596d67-40c0-7ca6-8000-05356a0c1d29
# results: [{'period_ending': datetime.date(2022, 12, 31), 'fiscal_period': 'FY', 'fi...
# provider: fmp
# warnings: None
# chart: None
# extra: {'metadata': {'arguments': {'provider_choices': {'provider': None}, 'standar...

# %% [markdown]
# ### Exploration Q2

# %% [markdown]
# To display the results as a dataframe we need to run add `to_df()` to the end of the command:
# 1. True
# 2. False

# %%
obb.equity.fundamental.balance("NFLX").to_df().transpose()
# Out:
#                                                                                            0  \
# period_ending                                                                     2022-12-31
# fiscal_period                                                                             FY
# fiscal_year                                                                             2022
# filing_date                                                                       2023-01-26
# accepted_date                                                            2023-01-26 16:03:50
# reported_currency                                                                        USD
# cash_and_cash_equivalents                                                       5147176000.0
# short_term_investments                                                           911276000.0
# cash_and_short_term_investments                                                 6058452000.0
# net_receivables                                                                 1586898000.0
# inventory                                                                      -1586898000.0
# other_current_assets                                                            3208021000.0
# total_current_assets                                                            9266473000.0
# plant_property_equipment_net                                                    1398257000.0
# intangible_assets                                                              32736713000.0
# goodwill_and_intangible_assets                                                 32736713000.0
# other_non_current_assets                                                        5193325000.0
# non_current_assets                                                             39328295000.0
# total_assets                                                                   48594768000.0
# accounts_payable                                                                 671513000.0
# short_term_debt                                                                          NaN
# current_deferred_revenue                                                        1264661000.0
# other_current_liabilities                                                       5994800000.0
# total_current_liabilities                                                       7930974000.0
# long_term_debt                                                                 14353076000.0
# other_non_current_liabilities                                                   5533317000.0
# total_non_current_liabilities                                                  19886393000.0
# total_liabilities                                                              27817367000.0
# common_stock                                                                    4637601000.0
# retained_earnings                                                              17181296000.0
# accumulated_other_comprehensive_income                                          -217306000.0
# other_total_shareholders_equity                                                 -824190000.0
# total_common_equity                                                            20777401000.0
# total_equity_non_controlling_interests                                         20777401000.0
# total_liabilities_and_shareholders_equity                                      48594768000.0
# total_liabilities_and_total_equity                                             48594768000.0
# total_investments                                                                911276000.0
# total_debt                                                                     14353076000.0
# net_debt                                                                        9205900000.0
# link                                       https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                 https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                            1  \
# period_ending                                                                     2021-12-31
# fiscal_period                                                                             FY
# fiscal_year                                                                             2021
# filing_date                                                                       2022-01-27
# accepted_date                                                            2022-01-27 17:03:33
# reported_currency                                                                        USD
# cash_and_cash_equivalents                                                       6027804000.0
# short_term_investments                                                                   NaN
# cash_and_short_term_investments                                                 6027804000.0
# net_receivables                                                                  804320000.0
# inventory                                                                       -804320000.0
# other_current_assets                                                            2042021000.0
# total_current_assets                                                            8069825000.0
# plant_property_equipment_net                                                    1323453000.0
# intangible_assets                                                              30919539000.0
# goodwill_and_intangible_assets                                                 30919539000.0
# other_non_current_assets                                                        4271846000.0
# non_current_assets                                                             36514838000.0
# total_assets                                                                   44584663000.0
# accounts_payable                                                                 837483000.0
# short_term_debt                                                                  699823000.0
# current_deferred_revenue                                                        1209342000.0
# other_current_liabilities                                                       5742318000.0
# total_current_liabilities                                                       8488966000.0
# long_term_debt                                                                 14693072000.0
# other_non_current_liabilities                                                   5553377000.0
# total_non_current_liabilities                                                  20246449000.0
# total_liabilities                                                              28735415000.0
# common_stock                                                                    4024561000.0
# retained_earnings                                                              12689372000.0
# accumulated_other_comprehensive_income                                           -40495000.0
# other_total_shareholders_equity                                                 -824190000.0
# total_common_equity                                                            15849248000.0
# total_equity_non_controlling_interests                                         15849248000.0
# total_liabilities_and_shareholders_equity                                      44584663000.0
# total_liabilities_and_total_equity                                             44584663000.0
# total_investments                                                                        NaN
# total_debt                                                                     15392895000.0
# net_debt                                                                        9365091000.0
# link                                       https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                 https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                            2  \
# period_ending                                                                     2020-12-31
# fiscal_period                                                                             FY
# fiscal_year                                                                             2020
# filing_date                                                                       2021-01-28
# accepted_date                                                            2021-01-28 16:21:59
# reported_currency                                                                        USD
# cash_and_cash_equivalents                                                       8205550000.0
# short_term_investments                                                                   NaN
# cash_and_short_term_investments                                                 8205550000.0
# net_receivables                                                                  610819000.0
# inventory                                                                       -610819000.0
# other_current_assets                                                            1556030000.0
# total_current_assets                                                            9761580000.0
# plant_property_equipment_net                                                     960183000.0
# intangible_assets                                                              25383950000.0
# goodwill_and_intangible_assets                                                 25383950000.0
# other_non_current_assets                                                        3174646000.0
# non_current_assets                                                             29518779000.0
# total_assets                                                                   39280359000.0
# accounts_payable                                                                 656183000.0
# short_term_debt                                                                  499878000.0
# current_deferred_revenue                                                        1117992000.0
# other_current_liabilities                                                       5531732000.0
# total_current_liabilities                                                       7805785000.0
# long_term_debt                                                                 15809095000.0
# other_non_current_liabilities                                                   4600239000.0
# total_non_current_liabilities                                                  20409334000.0
# total_liabilities                                                              28215119000.0
# common_stock                                                                    3447698000.0
# retained_earnings                                                               7573144000.0
# accumulated_other_comprehensive_income                                            44398000.0
# other_total_shareholders_equity                                                          NaN
# total_common_equity                                                            11065240000.0
# total_equity_non_controlling_interests                                         11065240000.0
# total_liabilities_and_shareholders_equity                                      39280359000.0
# total_liabilities_and_total_equity                                             39280359000.0
# total_investments                                                                        NaN
# total_debt                                                                     16308973000.0
# net_debt                                                                        8103423000.0
# link                                       https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                 https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                            3  \
# period_ending                                                                     2019-12-31
# fiscal_period                                                                             FY
# fiscal_year                                                                             2019
# filing_date                                                                       2020-01-29
# accepted_date                                                            2020-01-29 16:03:25
# reported_currency                                                                        USD
# cash_and_cash_equivalents                                                       5018437000.0
# short_term_investments                                                                   NaN
# cash_and_short_term_investments                                                 5018437000.0
# net_receivables                                                                  979068000.0
# inventory                                                                       -979068000.0
# other_current_assets                                                            1160067000.0
# total_current_assets                                                            6178504000.0
# plant_property_equipment_net                                                     565221000.0
# intangible_assets                                                              24504567000.0
# goodwill_and_intangible_assets                                                 24504567000.0
# other_non_current_assets                                                        2727420000.0
# non_current_assets                                                             27797208000.0
# total_assets                                                                   33975712000.0
# accounts_payable                                                                 674347000.0
# short_term_debt                                                                  843043000.0
# current_deferred_revenue                                                         924745000.0
# other_current_liabilities                                                       4413561000.0
# total_current_liabilities                                                       6855696000.0
# long_term_debt                                                                 14759260000.0
# other_non_current_liabilities                                                   4778599000.0
# total_non_current_liabilities                                                  19537859000.0
# total_liabilities                                                              26393555000.0
# common_stock                                                                    2793929000.0
# retained_earnings                                                               4811749000.0
# accumulated_other_comprehensive_income                                           -23521000.0
# other_total_shareholders_equity                                                          NaN
# total_common_equity                                                             7582157000.0
# total_equity_non_controlling_interests                                          7582157000.0
# total_liabilities_and_shareholders_equity                                      33975712000.0
# total_liabilities_and_total_equity                                             33975712000.0
# total_investments                                                                        NaN
# total_debt                                                                     14759260000.0
# net_debt                                                                        9740823000.0
# link                                       https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                 https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                            4
# period_ending                                                                     2018-12-31
# fiscal_period                                                                             FY
# fiscal_year                                                                             2018
# filing_date                                                                       2019-01-29
# accepted_date                                                            2019-01-29 17:12:16
# reported_currency                                                                        USD
# cash_and_cash_equivalents                                                       3794483000.0
# short_term_investments                                                                   NaN
# cash_and_short_term_investments                                                 3794483000.0
# net_receivables                                                                          NaN
# inventory                                                                                NaN
# other_current_assets                                                            5899652000.0
# total_current_assets                                                            9694135000.0
# plant_property_equipment_net                                                     418281000.0
# intangible_assets                                                              14960954000.0
# goodwill_and_intangible_assets                                                 14960954000.0
# other_non_current_assets                                                         901030000.0
# non_current_assets                                                             16280265000.0
# total_assets                                                                   25974400000.0
# accounts_payable                                                                 562985000.0
# short_term_debt                                                                  477417000.0
# current_deferred_revenue                                                         760899000.0
# other_current_liabilities                                                       4686019000.0
# total_current_liabilities                                                       6487320000.0
# long_term_debt                                                                 10360058000.0
# other_non_current_liabilities                                                   3888257000.0
# total_non_current_liabilities                                                  14248315000.0
# total_liabilities                                                              20735635000.0
# common_stock                                                                    2315988000.0
# retained_earnings                                                               2942359000.0
# accumulated_other_comprehensive_income                                           -19582000.0
# other_total_shareholders_equity                                                          NaN
# total_common_equity                                                             5238765000.0
# total_equity_non_controlling_interests                                          5238765000.0
# total_liabilities_and_shareholders_equity                                      25974400000.0
# total_liabilities_and_total_equity                                             25974400000.0
# total_investments                                                                        NaN
# total_debt                                                                     10360058000.0
# net_debt                                                                        6565575000.0
# link                                       https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                 https://www.sec.gov/Archives/edgar/data/106528...

# %% [markdown]
# ### Exploration Q3
#
# To get the income statement all we need to do is to change `balance` to `income` in the namespace:
# 1. True
# 2. False

# %%
obb.equity.fundamental.income("NFLX")
# Out:
# OBBject
#
# id: 06597ff3-255a-79c9-8000-2c8ba8caf8a0
# results: [{'period_ending': datetime.date(2022, 12, 31), 'fiscal_period': 'FY', 'fi...
# provider: fmp
# warnings: None
# chart: None
# extra: {'metadata': {'arguments': {'provider_choices': {'provider': None}, 'standar...

# %% [markdown]
# ### Exploration Q4

# %% [markdown]
# What is the value of NFLX net income in 2021 based on the cash flow statement?
#
# Input: [input] -> correct 5116228000.0

# %%
obb.equity.fundamental.cash("NFLX", provider="fmp").to_df().transpose()
# Out:
#                                                                                           0  \
# period_ending                                                                    2022-12-31
# fiscal_period                                                                            FY
# fiscal_year                                                                            2022
# filing_date                                                                      2023-01-26
# accepted_date                                                           2023-01-26 16:03:50
# reported_currency                                                                       USD
# net_income                                                                     4491924000.0
# depreciation_and_amortization                                                 14362814000.0
# deferred_income_tax                                                            -166550000.0
# stock_based_compensation                                                        575452000.0
# change_in_working_capital                                                      -758087000.0
# change_in_account_payable                                                      -158543000.0
# change_in_other_working_capital                                                -599544000.0
# change_in_other_non_cash_items                                               -16479296000.0
# net_cash_from_operating_activities                                             2026257000.0
# purchase_of_property_plant_and_equipment                                       -407729000.0
# acquisitions                                                                   -757387000.0
# purchase_of_investment_securities                                              -911276000.0
# sale_and_maturity_of_investments                                                757387000.0
# other_investing_activities                                                     -757387000.0
# net_cash_from_investing_activities                                            -2076392000.0
# repayment_of_debt                                                              -700000000.0
# issuance_of_common_equity                                                        35746000.0
# repurchase_of_common_equity                                                             NaN
# other_financing_activities                                                              NaN
# net_cash_from_financing_activities                                             -664254000.0
# effect_of_exchange_rate_changes_on_cash                                        -170140000.0
# net_change_in_cash_and_equivalents                                             -884529000.0
# cash_at_beginning_of_period                                                    6055111000.0
# cash_at_end_of_period                                                          5170582000.0
# operating_cash_flow                                                            2026257000.0
# capital_expenditure                                                            -407729000.0
# free_cash_flow                                                                 1618528000.0
# link                                      https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                           1  \
# period_ending                                                                    2021-12-31
# fiscal_period                                                                            FY
# fiscal_year                                                                            2021
# filing_date                                                                      2022-01-27
# accepted_date                                                           2022-01-27 17:03:33
# reported_currency                                                                       USD
# net_income                                                                     5116228000.0
# depreciation_and_amortization                                                 12438779000.0
# deferred_income_tax                                                             199548000.0
# stock_based_compensation                                                        403220000.0
# change_in_working_capital                                                      -241977000.0
# change_in_account_payable                                                       145115000.0
# change_in_other_working_capital                                                -387092000.0
# change_in_other_non_cash_items                                               -17523188000.0
# net_cash_from_operating_activities                                              392610000.0
# purchase_of_property_plant_and_equipment                                       -524585000.0
# acquisitions                                                                   -788349000.0
# purchase_of_investment_securities                                                       NaN
# sale_and_maturity_of_investments                                                        NaN
# other_investing_activities                                                      -26919000.0
# net_cash_from_investing_activities                                            -1339853000.0
# repayment_of_debt                                                              -500000000.0
# issuance_of_common_equity                                                       174414000.0
# repurchase_of_common_equity                                                    -600022000.0
# other_financing_activities                                                     -224168000.0
# net_cash_from_financing_activities                                            -1149776000.0
# effect_of_exchange_rate_changes_on_cash                                         -86740000.0
# net_change_in_cash_and_equivalents                                            -2183759000.0
# cash_at_beginning_of_period                                                    8238870000.0
# cash_at_end_of_period                                                          6055111000.0
# operating_cash_flow                                                             392610000.0
# capital_expenditure                                                            -524585000.0
# free_cash_flow                                                                 -131975000.0
# link                                      https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                           2  \
# period_ending                                                                    2020-12-31
# fiscal_period                                                                            FY
# fiscal_year                                                                            2020
# filing_date                                                                      2021-01-28
# accepted_date                                                           2021-01-28 16:21:59
# reported_currency                                                                       USD
# net_income                                                                     2761395000.0
# depreciation_and_amortization                                                 10922622000.0
# deferred_income_tax                                                              70066000.0
# stock_based_compensation                                                        415180000.0
# change_in_working_capital                                                       -31873000.0
# change_in_account_payable                                                       -41605000.0
# change_in_other_working_capital                                                   9732000.0
# change_in_other_non_cash_items                                               -11710313000.0
# net_cash_from_operating_activities                                             2427077000.0
# purchase_of_property_plant_and_equipment                                       -497923000.0
# acquisitions                                                                            NaN
# purchase_of_investment_securities                                                       NaN
# sale_and_maturity_of_investments                                                        NaN
# other_investing_activities                                                       -7431000.0
# net_cash_from_investing_activities                                             -505354000.0
# repayment_of_debt                                                                       NaN
# issuance_of_common_equity                                                       235406000.0
# repurchase_of_common_equity                                                             NaN
# other_financing_activities                                                     1001905000.0
# net_cash_from_financing_activities                                             1237311000.0
# effect_of_exchange_rate_changes_on_cash                                          36050000.0
# net_change_in_cash_and_equivalents                                             3195084000.0
# cash_at_beginning_of_period                                                    5043786000.0
# cash_at_end_of_period                                                          8238870000.0
# operating_cash_flow                                                            2427077000.0
# capital_expenditure                                                            -497923000.0
# free_cash_flow                                                                 1929154000.0
# link                                      https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                           3  \
# period_ending                                                                    2019-12-31
# fiscal_period                                                                            FY
# fiscal_year                                                                            2019
# filing_date                                                                      2020-01-29
# accepted_date                                                           2020-01-29 16:03:25
# reported_currency                                                                       USD
# net_income                                                                     1866916000.0
# depreciation_and_amortization                                                  9319826000.0
# deferred_income_tax                                                             -94443000.0
# stock_based_compensation                                                        405376000.0
# change_in_working_capital                                                        43043000.0
# change_in_account_payable                                                        96063000.0
# change_in_other_working_capital                                                 -53020000.0
# change_in_other_non_cash_items                                               -14428040000.0
# net_cash_from_operating_activities                                            -2887322000.0
# purchase_of_property_plant_and_equipment                                       -253035000.0
# acquisitions                                                                            NaN
# purchase_of_investment_securities                                                       NaN
# sale_and_maturity_of_investments                                                        NaN
# other_investing_activities                                                     -134029000.0
# net_cash_from_investing_activities                                             -387064000.0
# repayment_of_debt                                                                       NaN
# issuance_of_common_equity                                                        72490000.0
# repurchase_of_common_equity                                                             NaN
# other_financing_activities                                                     4433172000.0
# net_cash_from_financing_activities                                             4505662000.0
# effect_of_exchange_rate_changes_on_cash                                            469000.0
# net_change_in_cash_and_equivalents                                             1231745000.0
# cash_at_beginning_of_period                                                    3812041000.0
# cash_at_end_of_period                                                          5043786000.0
# operating_cash_flow                                                           -2887322000.0
# capital_expenditure                                                            -253035000.0
# free_cash_flow                                                                -3140357000.0
# link                                      https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                           4
# period_ending                                                                    2018-12-31
# fiscal_period                                                                            FY
# fiscal_year                                                                            2018
# filing_date                                                                      2019-01-29
# accepted_date                                                           2019-01-29 17:12:16
# reported_currency                                                                       USD
# net_income                                                                     1211242000.0
# depreciation_and_amortization                                                  7656457000.0
# deferred_income_tax                                                             -85520000.0
# stock_based_compensation                                                        320657000.0
# change_in_working_capital                                                       293767000.0
# change_in_account_payable                                                       199198000.0
# change_in_other_working_capital                                                  94569000.0
# change_in_other_non_cash_items                                               -12077082000.0
# net_cash_from_operating_activities                                            -2680479000.0
# purchase_of_property_plant_and_equipment                                       -212532000.0
# acquisitions                                                                            NaN
# purchase_of_investment_securities                                                       NaN
# sale_and_maturity_of_investments                                                        NaN
# other_investing_activities                                                     -126588000.0
# net_cash_from_investing_activities                                             -339120000.0
# repayment_of_debt                                                                       NaN
# issuance_of_common_equity                                                       124502000.0
# repurchase_of_common_equity                                                             NaN
# other_financing_activities                                                     3924025000.0
# net_cash_from_financing_activities                                             4048527000.0
# effect_of_exchange_rate_changes_on_cash                                         -39682000.0
# net_change_in_cash_and_equivalents                                              989246000.0
# cash_at_beginning_of_period                                                    2822795000.0
# cash_at_end_of_period                                                          3812041000.0
# operating_cash_flow                                                           -2680479000.0
# capital_expenditure                                                            -212532000.0
# free_cash_flow                                                                -2893011000.0
# link                                      https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                https://www.sec.gov/Archives/edgar/data/106528...

# %% [markdown]
# ### Exploration Q5

# %% [markdown]
# ### What are the peers of NFLX when we run the following command `obb.equity.compare.peers("NFLX").to_df()[1][0]`?
#
# 1. ['MSFT', 'META', 'GOOG', 'AAPL', 'AMZN']
# 2. ['SPY', 'QQQ', 'F']
# 3. ['PARA', 'ROKU', 'WBD', 'AMC', 'DIS', 'APE', 'PARAA']
# 4. ['XAU', 'DJI', 'VOO']

# %%
obb.equity.compare.peers("NFLX").to_df()[1][0]
# Out:
# ['PARA', 'ROKU', 'WBD', 'AMC', 'DIS', 'APE', 'PARAA']

# %% [markdown]
# ### Exploration Q6

# %% [markdown]
# To get the quarterly income statement of ROKU  we run the following command:
# 1. `obb.equity.fundamental.income_statement("ROKU", period="Q1", year=2021)`
# 2. `obb.equity.fundamental.income("ROKU", period="quarter")`
# 3. `obb.equity.fundamental.income("NFLX")`
# 4. `obb.equity.fundamental.income("ROKU", period="quarterly")`

# %%
obb.equity.fundamental.income("NFLX", period="quarter").to_df().transpose()
# Out:
#                                                                                              0  \
# period_ending                                                                       2023-09-30
# fiscal_period                                                                               Q3
# fiscal_year                                                                               2023
# filing_date                                                                         2023-10-20
# accepted_date                                                              2023-10-20 16:01:48
# reported_currency                                                                          USD
# revenue                                                                           8541668000.0
# cost_of_revenue                                                                   4930788000.0
# gross_profit                                                                      3610880000.0
# gross_profit_margin                                                                   0.422737
# general_and_admin_expense                                                          478591000.0
# research_and_development_expense                                                   657159000.0
# selling_and_marketing_expense                                                      558736000.0
# selling_general_and_admin_expense                                                 1037327000.0
# total_operating_expenses                                                          1694486000.0
# cost_and_expenses                                                                 6625274000.0
# interest_income                                                                    168218000.0
# total_interest_expense                                                             175563000.0
# depreciation_and_amortization                                                     3664013000.0
# ebitda                                                                            5748625000.0
# ebitda_margin                                                                          0.67301
# total_operating_income                                                            1916394000.0
# operating_income_margin                                                               0.224358
# total_other_income_expenses                                                         -7345000.0
# total_pre_tax_income                                                              1909049000.0
# pre_tax_income_margin                                                                 0.223498
# income_tax_expense                                                                 231627000.0
# consolidated_net_income                                                           1677422000.0
# net_income_margin                                                                     0.196381
# basic_earnings_per_share                                                                   3.8
# diluted_earnings_per_share                                                                3.73
# weighted_average_basic_shares_outstanding                                          441537000.0
# weighted_average_diluted_shares_outstanding                                        450011000.0
# link                                         https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                   https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                              1  \
# period_ending                                                                       2023-06-30
# fiscal_period                                                                               Q2
# fiscal_year                                                                               2023
# filing_date                                                                         2023-07-21
# accepted_date                                                              2023-07-21 16:02:00
# reported_currency                                                                          USD
# revenue                                                                           8187301000.0
# cost_of_revenue                                                                   4673470000.0
# gross_profit                                                                      3513831000.0
# gross_profit_margin                                                                   0.429181
# general_and_admin_expense                                                          401497000.0
# research_and_development_expense                                                   657983000.0
# selling_and_marketing_expense                                                      627168000.0
# selling_general_and_admin_expense                                                 1028665000.0
# total_operating_expenses                                                          1686648000.0
# cost_and_expenses                                                                 6360118000.0
# interest_income                                                                     26961000.0
# total_interest_expense                                                             174812000.0
# depreciation_and_amortization                                                     3526367000.0
# ebitda                                                                            5353550000.0
# ebitda_margin                                                                         0.653885
# total_operating_income                                                            1827183000.0
# operating_income_margin                                                               0.223173
# total_other_income_expenses                                                       -147851000.0
# total_pre_tax_income                                                              1679332000.0
# pre_tax_income_margin                                                                 0.205114
# income_tax_expense                                                                 191722000.0
# consolidated_net_income                                                           1487610000.0
# net_income_margin                                                                     0.181697
# basic_earnings_per_share                                                                  3.35
# diluted_earnings_per_share                                                                3.29
# weighted_average_basic_shares_outstanding                                          443881000.0
# weighted_average_diluted_shares_outstanding                                        451572000.0
# link                                         https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                   https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                              2  \
# period_ending                                                                       2023-03-31
# fiscal_period                                                                               Q1
# fiscal_year                                                                               2023
# filing_date                                                                         2023-04-21
# accepted_date                                                              2023-04-21 16:02:01
# reported_currency                                                                          USD
# revenue                                                                           8161503000.0
# cost_of_revenue                                                                   4803625000.0
# gross_profit                                                                      3357878000.0
# gross_profit_margin                                                                   0.411429
# general_and_admin_expense                                                          400924000.0
# research_and_development_expense                                                   687275000.0
# selling_and_marketing_expense                                                      555362000.0
# selling_general_and_admin_expense                                                  956286000.0
# total_operating_expenses                                                          1643561000.0
# cost_and_expenses                                                                 6447186000.0
# interest_income                                                                            NaN
# total_interest_expense                                                             245443000.0
# depreciation_and_amortization                                                     3550319000.0
# ebitda                                                                            5264636000.0
# ebitda_margin                                                                         0.645057
# total_operating_income                                                            1714317000.0
# operating_income_margin                                                               0.210049
# total_other_income_expenses                                                       -245443000.0
# total_pre_tax_income                                                              1468874000.0
# pre_tax_income_margin                                                                 0.179976
# income_tax_expense                                                                 163754000.0
# consolidated_net_income                                                           1305120000.0
# net_income_margin                                                                     0.159912
# basic_earnings_per_share                                                                  2.93
# diluted_earnings_per_share                                                                2.88
# weighted_average_basic_shares_outstanding                                          445244000.0
# weighted_average_diluted_shares_outstanding                                        452417000.0
# link                                         https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                   https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                              3  \
# period_ending                                                                       2022-12-31
# fiscal_period                                                                               Q4
# fiscal_year                                                                               2022
# filing_date                                                                         2023-01-26
# accepted_date                                                              2023-01-26 16:03:50
# reported_currency                                                                          USD
# revenue                                                                           7852053000.0
# cost_of_revenue                                                                   5404160000.0
# gross_profit                                                                      2447893000.0
# gross_profit_margin                                                                   0.311752
# general_and_admin_expense                                                          392453000.0
# research_and_development_expense                                                   673926000.0
# selling_and_marketing_expense                                                      831610000.0
# selling_general_and_admin_expense                                                 1224063000.0
# total_operating_expenses                                                          1897989000.0
# cost_and_expenses                                                                 7302149000.0
# interest_income                                                                   -339965000.0
# total_interest_expense                                                             510568000.0
# depreciation_and_amortization                                                     4038214000.0
# ebitda                                                                            4588118000.0
# ebitda_margin                                                                         0.584321
# total_operating_income                                                             549904000.0
# operating_income_margin                                                               0.070033
# total_other_income_expenses                                                       -510568000.0
# total_pre_tax_income                                                                39336000.0
# pre_tax_income_margin                                                                  0.00501
# income_tax_expense                                                                 -15948000.0
# consolidated_net_income                                                             55284000.0
# net_income_margin                                                                     0.007041
# basic_earnings_per_share                                                                  0.12
# diluted_earnings_per_share                                                                0.12
# weighted_average_basic_shares_outstanding                                          445200000.0
# weighted_average_diluted_shares_outstanding                                        451649000.0
# link                                         https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                   https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                              4
# period_ending                                                                       2022-09-30
# fiscal_period                                                                               Q3
# fiscal_year                                                                               2022
# filing_date                                                                         2022-10-20
# accepted_date                                                              2022-10-20 16:04:17
# reported_currency                                                                          USD
# revenue                                                                           7925589000.0
# cost_of_revenue                                                                   4788665000.0
# gross_profit                                                                      3136924000.0
# gross_profit_margin                                                                   0.395797
# general_and_admin_expense                                                          373213000.0
# research_and_development_expense                                                   662739000.0
# selling_and_marketing_expense                                                      567954000.0
# selling_general_and_admin_expense                                                  941167000.0
# total_operating_expenses                                                          1603906000.0
# cost_and_expenses                                                                 6392571000.0
# interest_income                                                                    261404000.0
# total_interest_expense                                                             172575000.0
# depreciation_and_amortization                                                     4000184000.0
# ebitda                                                                            5533202000.0
# ebitda_margin                                                                         0.698144
# total_operating_income                                                            1533018000.0
# operating_income_margin                                                               0.193426
# total_other_income_expenses                                                         88829000.0
# total_pre_tax_income                                                              1621847000.0
# pre_tax_income_margin                                                                 0.204634
# income_tax_expense                                                                 223605000.0
# consolidated_net_income                                                           1398242000.0
# net_income_margin                                                                     0.176421
# basic_earnings_per_share                                                                  3.14
# diluted_earnings_per_share                                                                 3.1
# weighted_average_basic_shares_outstanding                                          444878000.0
# weighted_average_diluted_shares_outstanding                                        450344000.0
# link                                         https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                   https://www.sec.gov/Archives/edgar/data/106528...

# %% [markdown]
# ## Analysis

# %% [markdown]
# Filter the Peers (Remove PARAA, APE) [multiple choice]
#
# Obtain the Historical data for all of the peers for the last 2 years
#
# Plot them <- we do this
#
# Install the TA and QA
#
# Plot the SMA against each other <- we do this and ask them to check which one makes the most sense
#
# Check which one is the most cointegrated and correlated with NFLX

# %% [markdown]
# ### Analysis Q1

# %% [markdown]
# Which of the following peers should we remove from the analysis:
# 1. PARAA
# 2. ROKU
# 3. APE
# 4. WBD
# 5. DIS

# %% [markdown]
# The reason we exclude APE is because it is defunct on September 2nd 2023.
#
# The reason we exclude PARAA is because the shares are Class A and are not available to the general public for trading.

# %% [markdown]
# ### Analysis Q2

# %% [markdown]
# To obtain the historical data for NFLX and its peers for the last 2 years we can run the following command:
#
# 1. `obb.equity.historical("NFLX", "ROKU", "WBD", "DIS", "APE", "PARAA", period="2y")`
# 2. `obb.equity.price.historical(symbol=["NFLX", "ROKU", "PARA", "AMC", "WBD", "DIS"], start_date="2021-01-01", provider="fmp")`
# 3. `obb.price.historical(symbols=["NFLX", "ROKU", "PARA", "AMC", "WBD", "DIS"], start_date="2021-01-01", provider="fmp")`
# 4. `obb.historical.price(symbols=["NFLX", "ROKU", "PARA", "AMC", "WBD", "DIS"], start_date="2021-01-01", provider="fmp")`

# %%
obb.equity.price.historical(symbol=["NFLX", "ROKU", "PARA", "AMC", "WBD", "DIS"], start_date="2021-01-01", provider="fmp")
# Out:
# OBBject
#
# id: 06598022-d522-7bbe-8000-cb0d5fa3e235
# results: [{'date': datetime.datetime(2024, 1, 4, 0, 0), 'open': 472.98, 'high': 480...
# provider: fmp
# warnings: None
# chart: None
# extra: {'metadata': {'arguments': {'provider_choices': {'provider': 'fmp'}, 'standa...

# %% [markdown]
# ### Analysis Q3

# %% [markdown]
# To calculate the SMA what OpenBB extension do we need to install?
# 1. openbb-technical
# 2. openbb-quantitative
# 3. openbb-ta
# 4. openbb-econometrics

# %% [markdown]
# ### Analysis Q4
# To run a cointegration and correlation test we need to use which OpenBB extension?
# 1. openbb-technical
# 2. openbb-quantitative
# 3. openbb-econometrics
# 4. openbb-statistics

# %% [markdown]
# Install the extensions and reload your kernel.

# %% [markdown]
# ### Analysis Q5
#
# To calculate the 20 SMA we need to run the following command for each of the peers:
# 1. `obb.technical.sma(data=data[data["symbol"] == "NFLX"], length=20)`
# 2. `obb.ta.sma(data=data[data["symbol"] == "NFLX"], length=20)`
# 3. `obb.technical.sma(data=data, length=20)`
# 4. `obb.ta.sma(data=data, length=20)`

# %%
data = obb.equity.price.historical(symbol=["NFLX", "ROKU", "PARA", "AMC", "WBD", "DIS"], start_date="2021-01-01", provider="fmp").to_df()
sma_nflx = obb.technical.sma(data=data[data["symbol"] == "NFLX"], length=20)
sma_nflx.to_df().tail()
# Out:
#      index     open      high       low   close   volume    vwap  \
# 751    751  492.000  492.8900  489.0700  490.51  1710492  490.67
# 752    752  490.370  492.2299  481.9350  486.88  2740555  486.03
# 753    753  483.185  484.6500  461.8600  468.50  5038623  469.38
# 754    754  467.320  475.0500  465.7727  470.26  3442594  471.16
# 755    755  472.980  480.7393  466.5300  474.67  3610567  475.15
#
#                label  adj_close  unadjusted_volume  change  change_percent  \
# 751  December 28, 23     490.51          1710500.0  -1.490        -0.30285
# 752  December 29, 23     486.88          2739500.0  -3.490        -0.71171
# 753   January 02, 24     468.50          5049400.0 -14.685        -3.04000
# 754   January 03, 24     470.26          3443700.0   2.940         0.62912
# 755   January 04, 24     474.67          3609169.0   1.690         0.35731
#
#      change_over_time symbol  close_SMA_20
# 751         -0.003028   NFLX      473.4140
# 752         -0.007117   NFLX      474.0595
# 753         -0.030400   NFLX      474.1975
# 754          0.006291   NFLX      475.0155
# 755          0.003573   NFLX      475.9915

# %% [markdown]
# ### Analysis Q6
#
# Which one of the following peers looks the most cointegrated with NFLX?
# 1. ROKU
# 2. WBD
# 3. DIS
# 4. AMC

# %% [markdown]
# ### Analysis Q7

# %%
obb.equity.price.historical(symbol=["NFLX", "ROKU", "PARA", "AMC", "WBD", "DIS"], start_date="2021-01-01", provider="fmp").to_df()
# Out:
#               open      high      low   close    volume    vwap  \
# date
# 2021-01-04   37.30   37.7600   36.310   36.60  12491900   36.89
# 2021-01-04   31.07   31.0700   29.770   30.63   7537147   30.49
# 2021-01-04   22.00   22.0000   20.000   20.10   2987380   20.70
# 2021-01-04  339.98  340.0000  316.460  317.90   4919713  323.46
# 2021-01-04  539.00  540.8000  515.085  522.86   4444407  524.49
# ...            ...       ...      ...     ...       ...     ...
# 2024-01-04    5.56    5.6000    5.250    5.30  22872100    5.38
# 2024-01-04   11.31   11.3850   11.180   11.35  19607992   11.30
# 2024-01-04   91.94   91.9400   90.000   90.56  11917320   90.54
# 2024-01-04   14.19   14.5300   14.010   14.49  10684207   14.37
# 2024-01-04  472.98  480.7393  466.530  474.67   3610567  475.15
#
#                      label   adj_close  unadjusted_volume  change  \
# date
# 2021-01-04  January 04, 21   33.750000         12491900.0   -0.70
# 2021-01-04  January 04, 21   30.629999          7537100.0   -0.44
# 2021-01-04  January 04, 21   20.100000          2987380.0   -1.90
# 2021-01-04  January 04, 21  317.899994          4919700.0  -22.08
# 2021-01-04  January 04, 21  522.859985          4444400.0  -16.14
# ...                    ...         ...                ...     ...
# 2024-01-04  January 04, 24    5.300000         22872100.0   -0.26
# 2024-01-04  January 04, 24   11.350000         18577422.0    0.04
# 2024-01-04  January 04, 24   90.560000         11896515.0   -1.38
# 2024-01-04  January 04, 24   14.490000         10439204.0    0.30
# 2024-01-04  January 04, 24  474.670000          3609169.0    1.69
#
#             change_percent  change_over_time symbol
# date
# 2021-01-04        -1.88000         -0.018800   PARA
# 2021-01-04        -1.42000         -0.014200    WBD
# 2021-01-04        -8.64000         -0.086400    AMC
# 2021-01-04        -6.49000         -0.064900   ROKU
# 2021-01-04        -2.99000         -0.029900   NFLX
# ...                    ...               ...    ...
# 2024-01-04        -4.68000         -0.046800    AMC
# 2024-01-04         0.35367          0.003537    WBD
# 2024-01-04        -1.50000         -0.015000    DIS
# 2024-01-04         2.11000          0.021100   PARA
# 2024-01-04         0.35731          0.003573   NFLX
#
# [4536 rows x 13 columns]

# %%
# transpose the data so that every symbols is a column and all rows are the closing prices
data = obb.equity.price.historical(symbol=["NFLX", "ROKU", "PARA", "AMC", "WBD", "DIS"], start_date="2021-01-01", provider="fmp").to_df().reset_index().pivot(index="date", columns="symbol", values="adj_close")
data.head()
# Out:
# symbol       AMC     DIS        NFLX   PARA        ROKU        WBD
# date
# 2021-01-04  20.1  177.10  522.859985  33.75  317.899994  30.629999
# 2021-01-05  19.8  177.86  520.799988  34.11  335.179993  31.520000
# 2021-01-06  20.1  178.54  500.489990  37.07  342.950012  34.250000
# 2021-01-07  20.5  178.00  508.890015  37.00  379.290009  34.400002
# 2021-01-08  21.4  178.11  510.399994  36.95  399.130005  34.630001

# %% [markdown]
# ### Analysis Q8

# %% [markdown]
# To run the cointegration test we need to run the following command:

# %%
coint_df = obb.econometrics.cointegration(data, columns=data.columns).to_df()
coint_df = coint_df.transpose().sort_values(by="pvalue").reset_index()
coint_df = coint_df[coint_df["index"].str.contains("NFLX")]
coint_df
# Out:
#         index           c     gamma     alpha   adfstat    pvalue
# 9    AMC/NFLX  -67.492319  0.523139 -0.013047 -2.093834  0.247001
# 11  NFLX/ROKU  286.494006  0.734570 -0.008442 -1.482127  0.542334
# 12   NFLX/WBD  283.420008  5.961022 -0.002704 -1.477240  0.544739
# 13  NFLX/PARA  281.898336  4.670904 -0.003254 -1.451680  0.557265
# 14   DIS/NFLX   46.478904  0.195856 -0.004082 -0.920262  0.781227

# %% [markdown]
# ### Analysis Q9

# %% [markdown]
# To create a correlation matrix we need to run the following command:
# 1. `obb.quantitative.correlation_matrix(data=data)`
# 2. `obb.technical.correlation_matrix(data=data)`
# 3. `obb.econometrics.correlation_matrix(data=data)`
# 4. `obb.statistics.correlation_matrix(data=data)`

# %%
corr_df = obb.econometrics.correlation_matrix(data).to_df()
corr_df[["NFLX", "comp_to"]].sort_values(by="NFLX", ascending=False)[1:]
# Out:
#        NFLX comp_to
# 4  0.736497    ROKU
# 1  0.684408     DIS
# 5  0.543955     WBD
# 0  0.485549     AMC
# 3  0.455198    PARA

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Select which one is the least risky to trade based on the financials, news, and price performance.
#
# Check for insider trading
#
# Suggest backtesting
