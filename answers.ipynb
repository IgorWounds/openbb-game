# %% [markdown]
# ## Introduction

# %% [markdown]
# Goals of this section:
#
# 1. Explain the game and its goal
# 2. Teach the user about the OpenBB Platform
# 3. Speak about the main strengths of the Platform
# 4. Introduce them to the topic we’ll be exploring

# %% [markdown]
# Requirements:
#
# 1. The user must be proficient in Python
# 2. The user should have an account on the OpenBB Hub
# 3. The user should have a FinancialModelingPrep API key set up in the Hub

# %% [markdown]
# The topic we'll be exploring is performing investment research on Netlifx (NFLX) and its peers for a pair trading strategy.

# %% [markdown]
# ### Introduction Q1
#
# The OpenBB Platform is:
#    1. Modular
#    2. Scalable
#    3. Secure
#    4. Open Source

# %% [markdown]
# ### Introduction Q2
#
# Pairs trading is a strategy where:
# 1. a trader buys one asset while shorting another. The main premise of the trade is that when the two pairs diverge, they will likely converge again resulting in profit for the trader.
# 2. a trader buys one asset while shorting another. The main premise of the trade is that when the two pairs diverge, they will likely diverge even further resulting in profit for the trader.
# 3. a trader buys both assets and holds them for a long time.
# 4. a trader buys low and sells high.

# %% [markdown]
# ### Introduction Q3
#
# For a Pairs trading strategy to work the best, the two assets should be:
#
# 1. highly correlated
# 2. highly uncorrelated
# 3. correlated and cointegrated
# 4. correlated with the S&P 500

# %% [markdown]
# ## Setup

# %% [markdown]
# Goals of this section:
#
# 1. Install the Platform
# 2. Point them to the Hub to set up their API keys
# 3. Log in to the Hub

# %% [markdown]
# ### Setup Q1
#
# To install the OpenBB Platform you need to:
#
# 1. Install Docker and run: `docker run -p 8888:8888 openbb/platform`
# 2. Run `pip install openbb-platform`
# 3. Turn on your computer and wait for the Platform to install itself
# 4. Run `pip install openbb`

# %% [markdown]
# ### Setup Q2
#
# To import the OpenBB Platform you need to:
# 1. `from openbb-platform import platform`
# 2. `import openbb-platform`
# 3. `from openbb import platform`
# 4. `from openbb import obb`

# %%
from openbb import obb

# %% [markdown]
# ### Setup Q3
#
# To connect to the Hub you need to run:
# 1. `obb.connect`
# 2. `obb.account.login(email='email', password='password')`
# 3. `obb.account.connect(email='email', password='password')`
# 4. `obb.login(email='email', password='password')`

# %%
# obb.account.login(email='email', password='password')

# %% [markdown]
# ## Exploration

# %% [markdown]
# Goals of this section:
#
# 1. Explore NFLX and its financials to justify why we want to trade its peers against it
# 2. Get the balance sheet
# 3. Get the income statement X value
# 4. Get the cash flow statement -> See if X is larger or smaller than Y
# 5. Find the Peers (suggest that the user explores them too)
# 6. Navigate to the right menu
# 7. Ask the user to obtain the X value for Y year and Z quarter of ROKU

# %% [markdown]
# ### Exploration Q1
#
# To analyze the NFLX balance sheet we need to access which namespace:
#
# 1. `obb.financials.balance_sheet`
# 2. `obb.fundamental.balance`
# 3. `obb.equity.fundamental.balance`
# 4. `obb.balance_sheet`

# %%
obb.equity.fundamental.balance("NFLX")
# Out:
# OBBject
#
# id: 065b10bd-5cce-71f7-8000-6486d735604e
# results: [{'period_ending': datetime.date(2022, 12, 31), 'fiscal_period': 'FY', 'fi...
# provider: fmp
# warnings: None
# chart: None
# extra: {'metadata': {'arguments': {'provider_choices': {'provider': None}, 'standar...

# %% [markdown]
# ### Exploration Q2
#
# To display the results as a dataframe we need to run add `to_df()` to the end of the command:
#
# 1. True
# 2. False

# %%
obb.equity.fundamental.balance("NFLX").to_df().transpose()
# Out:
#                                                                                         0  \
# period_ending                                                                  2022-12-31
# fiscal_period                                                                          FY
# fiscal_year                                                                          2022
# filing_date                                                                    2023-01-26
# accepted_date                                                         2023-01-26 16:03:50
# currency                                                                              USD
# cash_and_cash_equivalents                                                      5147176000
# short_term_investments                                                        911276000.0
# cash_and_short_term_investments                                                6058452000
# net_receivables                                                              1586898000.0
# inventory                                                                   -1586898000.0
# other_current_assets                                                           3208021000
# total_current_assets                                                           9266473000
# plant_property_equipment_net                                                   1398257000
# intangible_assets                                                             32736713000
# goodwill_and_intangible_assets                                                32736713000
# other_non_current_assets                                                       5193325000
# non_current_assets                                                            39328295000
# total_assets                                                                  48594768000
# accounts_payable                                                                671513000
# short_term_debt                                                                       NaN
# current_deferred_revenue                                                       1264661000
# other_current_liabilities                                                      5994800000
# total_current_liabilities                                                      7930974000
# long_term_debt                                                                14353076000
# other_non_current_liabilities                                                  5533317000
# total_non_current_liabilities                                                 19886393000
# total_liabilities                                                             27817367000
# common_stock                                                                   4637601000
# retained_earnings                                                             17181296000
# accumulated_other_comprehensive_income                                         -217306000
# other_total_stock_holders_equity                                             -824190000.0
# total_common_equity                                                           20777401000
# total_equity_non_controlling_interests                                        20777401000
# total_liabilities_shareholders_equity                                         48594768000
# total_liabilities_and_total_equity                                            48594768000
# total_investments                                                             911276000.0
# total_debt                                                                    14353076000
# net_debt                                                                       9205900000
# link                                    https://www.sec.gov/Archives/edgar/data/106528...
# final_link                              https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                         1  \
# period_ending                                                                  2021-12-31
# fiscal_period                                                                          FY
# fiscal_year                                                                          2021
# filing_date                                                                    2022-01-27
# accepted_date                                                         2022-01-27 17:03:33
# currency                                                                              USD
# cash_and_cash_equivalents                                                      6027804000
# short_term_investments                                                                NaN
# cash_and_short_term_investments                                                6027804000
# net_receivables                                                               804320000.0
# inventory                                                                    -804320000.0
# other_current_assets                                                           2042021000
# total_current_assets                                                           8069825000
# plant_property_equipment_net                                                   1323453000
# intangible_assets                                                             30919539000
# goodwill_and_intangible_assets                                                30919539000
# other_non_current_assets                                                       4271846000
# non_current_assets                                                            36514838000
# total_assets                                                                  44584663000
# accounts_payable                                                                837483000
# short_term_debt                                                               699823000.0
# current_deferred_revenue                                                       1209342000
# other_current_liabilities                                                      5742318000
# total_current_liabilities                                                      8488966000
# long_term_debt                                                                14693072000
# other_non_current_liabilities                                                  5553377000
# total_non_current_liabilities                                                 20246449000
# total_liabilities                                                             28735415000
# common_stock                                                                   4024561000
# retained_earnings                                                             12689372000
# accumulated_other_comprehensive_income                                          -40495000
# other_total_stock_holders_equity                                             -824190000.0
# total_common_equity                                                           15849248000
# total_equity_non_controlling_interests                                        15849248000
# total_liabilities_shareholders_equity                                         44584663000
# total_liabilities_and_total_equity                                            44584663000
# total_investments                                                                     NaN
# total_debt                                                                    15392895000
# net_debt                                                                       9365091000
# link                                    https://www.sec.gov/Archives/edgar/data/106528...
# final_link                              https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                         2  \
# period_ending                                                                  2020-12-31
# fiscal_period                                                                          FY
# fiscal_year                                                                          2020
# filing_date                                                                    2021-01-28
# accepted_date                                                         2021-01-28 16:21:59
# currency                                                                              USD
# cash_and_cash_equivalents                                                      8205550000
# short_term_investments                                                                NaN
# cash_and_short_term_investments                                                8205550000
# net_receivables                                                               610819000.0
# inventory                                                                    -610819000.0
# other_current_assets                                                           1556030000
# total_current_assets                                                           9761580000
# plant_property_equipment_net                                                    960183000
# intangible_assets                                                             25383950000
# goodwill_and_intangible_assets                                                25383950000
# other_non_current_assets                                                       3174646000
# non_current_assets                                                            29518779000
# total_assets                                                                  39280359000
# accounts_payable                                                                656183000
# short_term_debt                                                               499878000.0
# current_deferred_revenue                                                       1117992000
# other_current_liabilities                                                      5531732000
# total_current_liabilities                                                      7805785000
# long_term_debt                                                                15809095000
# other_non_current_liabilities                                                  4600239000
# total_non_current_liabilities                                                 20409334000
# total_liabilities                                                             28215119000
# common_stock                                                                   3447698000
# retained_earnings                                                              7573144000
# accumulated_other_comprehensive_income                                           44398000
# other_total_stock_holders_equity                                                      NaN
# total_common_equity                                                           11065240000
# total_equity_non_controlling_interests                                        11065240000
# total_liabilities_shareholders_equity                                         39280359000
# total_liabilities_and_total_equity                                            39280359000
# total_investments                                                                     NaN
# total_debt                                                                    16308973000
# net_debt                                                                       8103423000
# link                                    https://www.sec.gov/Archives/edgar/data/106528...
# final_link                              https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                         3  \
# period_ending                                                                  2019-12-31
# fiscal_period                                                                          FY
# fiscal_year                                                                          2019
# filing_date                                                                    2020-01-29
# accepted_date                                                         2020-01-29 16:03:25
# currency                                                                              USD
# cash_and_cash_equivalents                                                      5018437000
# short_term_investments                                                                NaN
# cash_and_short_term_investments                                                5018437000
# net_receivables                                                               979068000.0
# inventory                                                                    -979068000.0
# other_current_assets                                                           1160067000
# total_current_assets                                                           6178504000
# plant_property_equipment_net                                                    565221000
# intangible_assets                                                             24504567000
# goodwill_and_intangible_assets                                                24504567000
# other_non_current_assets                                                       2727420000
# non_current_assets                                                            27797208000
# total_assets                                                                  33975712000
# accounts_payable                                                                674347000
# short_term_debt                                                               843043000.0
# current_deferred_revenue                                                        924745000
# other_current_liabilities                                                      4413561000
# total_current_liabilities                                                      6855696000
# long_term_debt                                                                14759260000
# other_non_current_liabilities                                                  4778599000
# total_non_current_liabilities                                                 19537859000
# total_liabilities                                                             26393555000
# common_stock                                                                   2793929000
# retained_earnings                                                              4811749000
# accumulated_other_comprehensive_income                                          -23521000
# other_total_stock_holders_equity                                                      NaN
# total_common_equity                                                            7582157000
# total_equity_non_controlling_interests                                         7582157000
# total_liabilities_shareholders_equity                                         33975712000
# total_liabilities_and_total_equity                                            33975712000
# total_investments                                                                     NaN
# total_debt                                                                    14759260000
# net_debt                                                                       9740823000
# link                                    https://www.sec.gov/Archives/edgar/data/106528...
# final_link                              https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                         4
# period_ending                                                                  2018-12-31
# fiscal_period                                                                          FY
# fiscal_year                                                                          2018
# filing_date                                                                    2019-01-29
# accepted_date                                                         2019-01-29 17:12:16
# currency                                                                              USD
# cash_and_cash_equivalents                                                      3794483000
# short_term_investments                                                                NaN
# cash_and_short_term_investments                                                3794483000
# net_receivables                                                                       NaN
# inventory                                                                             NaN
# other_current_assets                                                           5899652000
# total_current_assets                                                           9694135000
# plant_property_equipment_net                                                    418281000
# intangible_assets                                                             14960954000
# goodwill_and_intangible_assets                                                14960954000
# other_non_current_assets                                                        901030000
# non_current_assets                                                            16280265000
# total_assets                                                                  25974400000
# accounts_payable                                                                562985000
# short_term_debt                                                               477417000.0
# current_deferred_revenue                                                        760899000
# other_current_liabilities                                                      4686019000
# total_current_liabilities                                                      6487320000
# long_term_debt                                                                10360058000
# other_non_current_liabilities                                                  3888257000
# total_non_current_liabilities                                                 14248315000
# total_liabilities                                                             20735635000
# common_stock                                                                   2315988000
# retained_earnings                                                              2942359000
# accumulated_other_comprehensive_income                                          -19582000
# other_total_stock_holders_equity                                                      NaN
# total_common_equity                                                            5238765000
# total_equity_non_controlling_interests                                         5238765000
# total_liabilities_shareholders_equity                                         25974400000
# total_liabilities_and_total_equity                                            25974400000
# total_investments                                                                     NaN
# total_debt                                                                    10360058000
# net_debt                                                                       6565575000
# link                                    https://www.sec.gov/Archives/edgar/data/106528...
# final_link                              https://www.sec.gov/Archives/edgar/data/106528...

# %% [markdown]
# ### Exploration Q3
#
# To get the income statement all we need to do is to change `balance` to `income` in the namespace:
# 1. True
# 2. False

# %%
obb.equity.fundamental.income("NFLX")
# Out:
# OBBject
#
# id: 065b10bd-7bce-7bdd-8000-007f3398c133
# results: [{'period_ending': datetime.date(2023, 12, 31), 'fiscal_period': 'FY', 'fi...
# provider: fmp
# warnings: None
# chart: None
# extra: {'metadata': {'arguments': {'provider_choices': {'provider': None}, 'standar...

# %% [markdown]
# ### Exploration Q4
#
# What is the value of NFLX net income in 2021 based on the cash flow statement?

# %%
obb.equity.fundamental.cash("NFLX", provider="fmp").to_df().transpose()
# Out:
#                                                                                           0  \
# period_ending                                                                    2023-12-31
# fiscal_period                                                                            FY
# fiscal_year                                                                            2023
# filing_date                                                                      2024-01-23
# accepted_date                                                           2024-01-23 16:02:17
# reported_currency                                                                       USD
# net_income                                                                       5407990000
# depreciation_and_amortization                                                   14554384000
# deferred_income_tax                                                              -459359000
# stock_based_compensation                                                          339368000
# change_in_working_capital                                                          93502000
# change_in_account_payable                                                          93502000
# changes_in_other_working_capital                                                  -93502000
# changes_in_other_non_cash_items                                                -12568082000
# net_cash_from_operating_activities                                               7274301000
# purchase_of_property_plant_and_equipment                                         -348552000
# acquisitions                                                                            NaN
# purchase_of_investment_securities                                              -504862000.0
# sale_and_maturity_of_investments                                               1395165000.0
# other_investing_activities                                                              NaN
# net_cash_from_investing_activities                                                541751000
# repayment_of_debt                                                                       NaN
# issuance_of_common_equity                                                         169990000
# repurchase_of_common_equity                                                   -6045347000.0
# other_financing_activities                                                      -75446000.0
# net_cash_from_financing_activities                                              -5950803000
# effect_of_exchange_rate_changes_on_cash                                            82684000
# net_change_in_cash_and_equivalents                                               1947933000
# cash_at_end_of_period                                                            7118515000
# cash_at_beginning_of_period                                                      5170582000
# operating_cash_flow                                                              7274301000
# capital_expenditure                                                              -348552000
# free_cash_flow                                                                   6925749000
# link                                      https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                           1  \
# period_ending                                                                    2022-12-31
# fiscal_period                                                                            FY
# fiscal_year                                                                            2022
# filing_date                                                                      2023-01-26
# accepted_date                                                           2023-01-26 16:03:50
# reported_currency                                                                       USD
# net_income                                                                       4491924000
# depreciation_and_amortization                                                   14362814000
# deferred_income_tax                                                              -166550000
# stock_based_compensation                                                          575452000
# change_in_working_capital                                                        -758087000
# change_in_account_payable                                                        -158543000
# changes_in_other_working_capital                                                 -599544000
# changes_in_other_non_cash_items                                                -16479296000
# net_cash_from_operating_activities                                               2026257000
# purchase_of_property_plant_and_equipment                                         -407729000
# acquisitions                                                                   -757387000.0
# purchase_of_investment_securities                                              -911276000.0
# sale_and_maturity_of_investments                                                757387000.0
# other_investing_activities                                                     -757387000.0
# net_cash_from_investing_activities                                              -2076392000
# repayment_of_debt                                                              -700000000.0
# issuance_of_common_equity                                                          35746000
# repurchase_of_common_equity                                                             NaN
# other_financing_activities                                                              NaN
# net_cash_from_financing_activities                                               -664254000
# effect_of_exchange_rate_changes_on_cash                                          -170140000
# net_change_in_cash_and_equivalents                                               -884529000
# cash_at_end_of_period                                                            5170582000
# cash_at_beginning_of_period                                                      6055111000
# operating_cash_flow                                                              2026257000
# capital_expenditure                                                              -407729000
# free_cash_flow                                                                   1618528000
# link                                      https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                           2  \
# period_ending                                                                    2021-12-31
# fiscal_period                                                                            FY
# fiscal_year                                                                            2021
# filing_date                                                                      2022-01-27
# accepted_date                                                           2022-01-27 17:03:33
# reported_currency                                                                       USD
# net_income                                                                       5116228000
# depreciation_and_amortization                                                   12438779000
# deferred_income_tax                                                               199548000
# stock_based_compensation                                                          403220000
# change_in_working_capital                                                        -241977000
# change_in_account_payable                                                         145115000
# changes_in_other_working_capital                                                 -387092000
# changes_in_other_non_cash_items                                                -17523188000
# net_cash_from_operating_activities                                                392610000
# purchase_of_property_plant_and_equipment                                         -524585000
# acquisitions                                                                   -788349000.0
# purchase_of_investment_securities                                                       NaN
# sale_and_maturity_of_investments                                                        NaN
# other_investing_activities                                                      -26919000.0
# net_cash_from_investing_activities                                              -1339853000
# repayment_of_debt                                                              -500000000.0
# issuance_of_common_equity                                                         174414000
# repurchase_of_common_equity                                                    -600022000.0
# other_financing_activities                                                     -224168000.0
# net_cash_from_financing_activities                                              -1149776000
# effect_of_exchange_rate_changes_on_cash                                           -86740000
# net_change_in_cash_and_equivalents                                              -2183759000
# cash_at_end_of_period                                                            6055111000
# cash_at_beginning_of_period                                                      8238870000
# operating_cash_flow                                                               392610000
# capital_expenditure                                                              -524585000
# free_cash_flow                                                                   -131975000
# link                                      https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                           3  \
# period_ending                                                                    2020-12-31
# fiscal_period                                                                            FY
# fiscal_year                                                                            2020
# filing_date                                                                      2021-01-28
# accepted_date                                                           2021-01-28 16:21:59
# reported_currency                                                                       USD
# net_income                                                                       2761395000
# depreciation_and_amortization                                                   10922622000
# deferred_income_tax                                                                70066000
# stock_based_compensation                                                          415180000
# change_in_working_capital                                                         -31873000
# change_in_account_payable                                                         -41605000
# changes_in_other_working_capital                                                    9732000
# changes_in_other_non_cash_items                                                -11710313000
# net_cash_from_operating_activities                                               2427077000
# purchase_of_property_plant_and_equipment                                         -497923000
# acquisitions                                                                            NaN
# purchase_of_investment_securities                                                       NaN
# sale_and_maturity_of_investments                                                        NaN
# other_investing_activities                                                       -7431000.0
# net_cash_from_investing_activities                                               -505354000
# repayment_of_debt                                                                       NaN
# issuance_of_common_equity                                                         235406000
# repurchase_of_common_equity                                                             NaN
# other_financing_activities                                                     1001905000.0
# net_cash_from_financing_activities                                               1237311000
# effect_of_exchange_rate_changes_on_cash                                            36050000
# net_change_in_cash_and_equivalents                                               3195084000
# cash_at_end_of_period                                                            8238870000
# cash_at_beginning_of_period                                                      5043786000
# operating_cash_flow                                                              2427077000
# capital_expenditure                                                              -497923000
# free_cash_flow                                                                   1929154000
# link                                      https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                https://www.sec.gov/Archives/edgar/data/106528...
#
#                                                                                           4
# period_ending                                                                    2019-12-31
# fiscal_period                                                                            FY
# fiscal_year                                                                            2019
# filing_date                                                                      2020-01-29
# accepted_date                                                           2020-01-29 16:03:25
# reported_currency                                                                       USD
# net_income                                                                       1866916000
# depreciation_and_amortization                                                    9319826000
# deferred_income_tax                                                               -94443000
# stock_based_compensation                                                          405376000
# change_in_working_capital                                                          43043000
# change_in_account_payable                                                          96063000
# changes_in_other_working_capital                                                  -53020000
# changes_in_other_non_cash_items                                                -14428040000
# net_cash_from_operating_activities                                              -2887322000
# purchase_of_property_plant_and_equipment                                         -253035000
# acquisitions                                                                            NaN
# purchase_of_investment_securities                                                       NaN
# sale_and_maturity_of_investments                                                        NaN
# other_investing_activities                                                     -134029000.0
# net_cash_from_investing_activities                                               -387064000
# repayment_of_debt                                                                       NaN
# issuance_of_common_equity                                                          72490000
# repurchase_of_common_equity                                                             NaN
# other_financing_activities                                                     4433172000.0
# net_cash_from_financing_activities                                               4505662000
# effect_of_exchange_rate_changes_on_cash                                              469000
# net_change_in_cash_and_equivalents                                               1231745000
# cash_at_end_of_period                                                            5043786000
# cash_at_beginning_of_period                                                      3812041000
# operating_cash_flow                                                             -2887322000
# capital_expenditure                                                              -253035000
# free_cash_flow                                                                  -3140357000
# link                                      https://www.sec.gov/Archives/edgar/data/106528...
# final_link                                https://www.sec.gov/Archives/edgar/data/106528...

# %% [markdown]
# ### Exploration Q5
# What are the peers of NFLX when we run the following command `obb.equity.compare.peers("NFLX").to_df()[1][0]`?
#
# 1. ['MSFT', 'META', 'GOOG', 'AAPL', 'AMZN']
# 2. ['SPY', 'QQQ', 'F']
# 3. ['PARA', 'ROKU', 'WBD', 'AMC', 'DIS', 'APE', 'PARAA']
# 4. ['XAU', 'DJI', 'VOO']

# %%
obb.equity.compare.peers("NFLX").to_df()[1][0]
# Out:
# ['PARA', 'ROKU', 'WBD', 'AMC', 'DIS', 'APE', 'PARAA']

# %% [markdown]
# ### Exploration Q6
#
# To get the quarterly income statement of ROKU  we run the following command:
#
# 1. `obb.equity.fundamental.income_statement("ROKU", period="Q1", year=2021)`
# 2. `obb.equity.fundamental.income("ROKU", period="quarter")`
# 3. `obb.equity.fundamental.income("NFLX")`
# 4. `obb.equity.fundamental.income("ROKU", period="quarterly")`

# %%
obb.equity.fundamental.income("ROKU", period="quarter").to_df().transpose()
# Out:
#                                                                                              0  \
# period_ending                                                                       2023-09-30
# fiscal_period                                                                               Q3
# fiscal_year                                                                               2023
# filing_date                                                                         2023-11-02
# accepted_date                                                              2023-11-02 16:22:49
# reported_currency                                                                          USD
# revenue                                                                              912018000
# cost_of_revenue                                                                      543195000
# gross_profit                                                                         368823000
# gross_profit_ratio                                                                    0.404403
# research_and_development_expense                                                     282201000
# general_and_admin_expense                                                            128717000
# selling_and_marketing_expense                                                        307694000
# selling_general_and_admin_expense                                                    436411000
# other_expenses                                                                        22912000
# total_operating_expenses                                                             718612000
# cost_and_expenses                                                                   1261807000
# interest_expense                                                                         10000
# depreciation_and_amortization                                                         33471000
# ebitda                                                                              -293406000
# ebitda_margin                                                                        -0.321711
# operating_income                                                                    -349789000
# operating_income_ratio                                                               -0.383533
# total_other_income_expenses_net                                                       22912000
# income_before_tax                                                                   -326887000
# income_before_tax_ratio                                                              -0.358422
# income_tax_expense                                                                     3184000
# consolidated_net_income                                                             -330071000
# net_income_ratio                                                                     -0.361913
# basic_earnings_per_share                                                                 -2.33
# diluted_earnings_per_share                                                               -2.33
# weighted_average_basic_shares_outstanding                                            141877000
# weighted_average_diluted_shares_outstanding                                          141877000
# link                                         https://www.sec.gov/Archives/edgar/data/142843...
# final_link                                   https://www.sec.gov/Archives/edgar/data/142843...
#
#                                                                                              1  \
# period_ending                                                                       2023-06-30
# fiscal_period                                                                               Q2
# fiscal_year                                                                               2023
# filing_date                                                                         2023-07-28
# accepted_date                                                              2023-07-28 16:08:06
# reported_currency                                                                          USD
# revenue                                                                              847186000
# cost_of_revenue                                                                      468915000
# gross_profit                                                                         378271000
# gross_profit_ratio                                                                    0.446503
# research_and_development_expense                                                     192387000
# general_and_admin_expense                                                            115877000
# selling_and_marketing_expense                                                        195967000
# selling_general_and_admin_expense                                                    311844000
# other_expenses                                                                        19999000
# total_operating_expenses                                                             504231000
# cost_and_expenses                                                                    973146000
# interest_expense                                                                          4000
# depreciation_and_amortization                                                         33776000
# ebitda                                                                               -72185000
# ebitda_margin                                                                        -0.085206
# operating_income                                                                    -125960000
# operating_income_ratio                                                                -0.14868
# total_other_income_expenses_net                                                       19999000
# income_before_tax                                                                   -105965000
# income_before_tax_ratio                                                              -0.125079
# income_tax_expense                                                                     1630000
# consolidated_net_income                                                             -107595000
# net_income_ratio                                                                     -0.127003
# basic_earnings_per_share                                                                 -0.76
# diluted_earnings_per_share                                                               -0.76
# weighted_average_basic_shares_outstanding                                            141033000
# weighted_average_diluted_shares_outstanding                                          141033000
# link                                         https://www.sec.gov/Archives/edgar/data/142843...
# final_link                                   https://www.sec.gov/Archives/edgar/data/142843...
#
#                                                                                              2  \
# period_ending                                                                       2023-03-31
# fiscal_period                                                                               Q1
# fiscal_year                                                                               2023
# filing_date                                                                         2023-04-27
# accepted_date                                                              2023-04-27 16:09:06
# reported_currency                                                                          USD
# revenue                                                                              740990000
# cost_of_revenue                                                                      403393000
# gross_profit                                                                         337597000
# gross_profit_ratio                                                                    0.455603
# research_and_development_expense                                                     220085000
# general_and_admin_expense                                                             96053000
# selling_and_marketing_expense                                                        233919000
# selling_general_and_admin_expense                                                    329972000
# other_expenses                                                                        23101000
# total_operating_expenses                                                             550057000
# cost_and_expenses                                                                    953450000
# interest_expense                                                                        681000
# depreciation_and_amortization                                                         54038000
# ebitda                                                                              -158422000
# ebitda_margin                                                                        -0.213798
# operating_income                                                                    -212460000
# operating_income_ratio                                                               -0.286725
# total_other_income_expenses_net                                                       22420000
# income_before_tax                                                                   -190040000
# income_before_tax_ratio                                                              -0.256468
# income_tax_expense                                                                     3564000
# consolidated_net_income                                                             -193604000
# net_income_ratio                                                                     -0.261277
# basic_earnings_per_share                                                                 -1.38
# diluted_earnings_per_share                                                               -1.38
# weighted_average_basic_shares_outstanding                                            140333000
# weighted_average_diluted_shares_outstanding                                          140333000
# link                                         https://www.sec.gov/Archives/edgar/data/142843...
# final_link                                   https://www.sec.gov/Archives/edgar/data/142843...
#
#                                                                                              3  \
# period_ending                                                                       2022-12-31
# fiscal_period                                                                               Q4
# fiscal_year                                                                               2022
# filing_date                                                                         2023-02-16
# accepted_date                                                              2023-02-16 16:51:10
# reported_currency                                                                          USD
# revenue                                                                              867056000
# cost_of_revenue                                                                      502679000
# gross_profit                                                                         364377000
# gross_profit_ratio                                                                    0.420246
# research_and_development_expense                                                     220670000
# general_and_admin_expense                                                             96043000
# selling_and_marketing_expense                                                        297562000
# selling_general_and_admin_expense                                                    393605000
# other_expenses                                                                        13614000
# total_operating_expenses                                                             614275000
# cost_and_expenses                                                                   1116954000
# interest_expense                                                                       1888000
# depreciation_and_amortization                                                         41003000
# ebitda                                                                              -208895000
# ebitda_margin                                                                        -0.240924
# operating_income                                                                    -249898000
# operating_income_ratio                                                               -0.288214
# total_other_income_expenses_net                                                       11726000
# income_before_tax                                                                   -238172000
# income_before_tax_ratio                                                               -0.27469
# income_tax_expense                                                                     -975000
# consolidated_net_income                                                             -237197000
# net_income_ratio                                                                     -0.273566
# basic_earnings_per_share                                                                  -1.7
# diluted_earnings_per_share                                                                -1.7
# weighted_average_basic_shares_outstanding                                            139658000
# weighted_average_diluted_shares_outstanding                                          139658000
# link                                         https://www.sec.gov/Archives/edgar/data/142843...
# final_link                                   https://www.sec.gov/Archives/edgar/data/142843...
#
#                                                                                              4
# period_ending                                                                       2022-09-30
# fiscal_period                                                                               Q3
# fiscal_year                                                                               2022
# filing_date                                                                         2022-11-03
# accepted_date                                                              2022-11-03 16:07:42
# reported_currency                                                                          USD
# revenue                                                                              761373000
# cost_of_revenue                                                                      404586000
# gross_profit                                                                         356787000
# gross_profit_ratio                                                                     0.46861
# research_and_development_expense                                                     207608000
# general_and_admin_expense                                                             86804000
# selling_and_marketing_expense                                                        209364000
# selling_general_and_admin_expense                                                    296168000
# other_expenses                                                                        27914000
# total_operating_expenses                                                             503776000
# cost_and_expenses                                                                    908362000
# interest_expense                                                                       1157000
# depreciation_and_amortization                                                         56546000
# ebitda                                                                               -90443000
# ebitda_margin                                                                        -0.118789
# operating_income                                                                    -146989000
# operating_income_ratio                                                               -0.193058
# total_other_income_expenses_net                                                       26757000
# income_before_tax                                                                   -120232000
# income_before_tax_ratio                                                              -0.157915
# income_tax_expense                                                                     1951000
# consolidated_net_income                                                             -122183000
# net_income_ratio                                                                     -0.160477
# basic_earnings_per_share                                                                 -0.88
# diluted_earnings_per_share                                                               -0.88
# weighted_average_basic_shares_outstanding                                            138571000
# weighted_average_diluted_shares_outstanding                                          138571000
# link                                         https://www.sec.gov/Archives/edgar/data/142843...
# final_link                                   https://www.sec.gov/Archives/edgar/data/142843...

# %% [markdown]
# ## Analysis

# %% [markdown]
# Goals of this section:
#
# 1. Filter the Peers (Remove PARAA, APE)
# 2. Obtain the historical price data for all of the peers for the last 2 years
# 3. Install the TA and QA extension
# 4. Check which one is the most cointegrated and correlated with PARA

# %% [markdown]
# ### Analysis Q1
#
# Which of the following peers should we remove from the analysis:
#
# 1. PARAA
# 2. ROKU
# 3. APE
# 4. WBD
# 5. DIS

# %% [markdown]
# The reason we exclude APE is because it is defunct on September 2nd 2023.
#
# The reason we exclude PARAA is because the shares are Class A and are not available to the general public for trading.

# %% [markdown]
# ### Analysis Q2
#
# To obtain the historical data for NFLX and its peers for the last 2 years we can run the following command:
#
# 1. `obb.equity.historical("NFLX", "ROKU", "WBD", "DIS", "APE", "PARAA", period="2y")`
# 2. `obb.equity.price.historical(symbol=["NFLX", "ROKU", "PARA", "AMC", "WBD", "DIS"], start_date="2021-01-01", provider="fmp")`
# 3. `obb.price.historical(symbols=["NFLX", "ROKU", "PARA", "AMC", "WBD", "DIS"], start_date="2021-01-01", provider="fmp")`
# 4. `obb.historical.price(symbols=["NFLX", "ROKU", "PARA", "AMC", "WBD", "DIS"], start_date="2021-01-01", provider="fmp")`

# %%
data = obb.equity.price.historical(symbol=["NFLX", "ROKU", "PARA", "AMC", "WBD", "DIS"], start_date="2021-01-01", provider="fmp")
data.to_df()
# Out:
#               open    high       low   close    volume    vwap  \
# date
# 2021-01-04   37.30   37.76   36.3100   36.60  12491900   36.89
# 2021-01-04   31.07   31.07   29.7700   30.63   7537147   30.49
# 2021-01-04   22.00   22.00   20.0000   20.10   2987380   20.70
# 2021-01-04  339.98  340.00  316.4600  317.90   4919713  323.46
# 2021-01-04  539.00  540.80  515.0850  522.86   4444407  524.49
# ...            ...     ...       ...     ...       ...     ...
# 2024-01-23    4.53    4.72    4.3300    4.33  12624800    4.46
# 2024-01-23   10.65   10.73   10.4445   10.54  15639748   10.53
# 2024-01-23   95.43   95.89   93.1750   93.77  11526990   93.86
# 2024-01-23   13.90   13.98   13.6500   13.68   9337559   13.75
# 2024-01-23  492.00  498.96  481.4000  492.19  12198593  491.39
#
#                      label   adj_close  unadjusted_volume  change  \
# date
# 2021-01-04  January 04, 21   33.650000         12491900.0   -0.70
# 2021-01-04  January 04, 21   30.629999          7537100.0   -0.44
# 2021-01-04  January 04, 21   20.100000          2987380.0   -1.90
# 2021-01-04  January 04, 21  317.899994          4919700.0  -22.08
# 2021-01-04  January 04, 21  522.859985          4444400.0  -16.14
# ...                    ...         ...                ...     ...
# 2024-01-23  January 23, 24    4.330000         12624800.0   -0.20
# 2024-01-23  January 23, 24   10.540000         14146365.0   -0.11
# 2024-01-23  January 23, 24   93.770000         11483128.0   -1.66
# 2024-01-23  January 23, 24   13.680000          8816829.0   -0.22
# 2024-01-23  January 23, 24  492.190000         11097538.0    0.19
#
#             change_percent  change_over_time symbol
# date
# 2021-01-04       -1.880000         -0.018800   PARA
# 2021-01-04       -1.420000         -0.014200    WBD
# 2021-01-04       -8.640000         -0.086400    AMC
# 2021-01-04       -6.490000         -0.064900   ROKU
# 2021-01-04       -2.990000         -0.029900   NFLX
# ...                    ...               ...    ...
# 2024-01-23       -4.420000         -0.044200    AMC
# 2024-01-23       -1.030000         -0.010300    WBD
# 2024-01-23       -1.740000         -0.017400    DIS
# 2024-01-23       -1.580000         -0.015800   PARA
# 2024-01-23        0.038618          0.000386   NFLX
#
# [4608 rows x 13 columns]

# %% [markdown]
# ### Analysis Q3
#
# To calculate the SMA what OpenBB extension do we need to install?
#
# 1. openbb-technical
# 2. openbb-quantitative
# 3. openbb-ta
# 4. openbb-econometrics

# %% [markdown]
# ### Analysis Q4
#
# To run a cointegration and correlation test we need to use which OpenBB extension?
#
# 1. openbb-technical
# 2. openbb-quantitative
# 3. openbb-econometrics
# 4. openbb-statistics

# %% [markdown]
# **Note**: Install the extensions and reload your kernel.

# %% [markdown]
# ### Analysis Q5
#
# To calculate the 20 SMA we need to run the following command for each of the peers:
#
# 1. `obb.technical.sma(data=data[data["symbol"] == "NFLX"], length=20)`
# 2. `obb.ta.sma(data=data[data["symbol"] == "NFLX"], length=20)`
# 3. `obb.technical.sma(data=data, length=20)`
# 4. `obb.ta.sma(data=data, length=20)`

# %%
data = obb.equity.price.historical(symbol=["NFLX", "ROKU", "PARA", "AMC", "WBD", "DIS"], start_date="2021-01-01", provider="fmp").to_df()
sma_nflx = obb.technical.sma(data=data[data["symbol"] == "NFLX"], length=20)
sma_nflx.to_df().tail()
# Out:
#      index    open    high       low   close    volume    vwap  \
# 763    763  484.50  486.21  475.2642  480.33   4801993  479.85
# 764    764  480.03  485.77  478.0200  485.31   4052869  483.33
# 765    765  484.98  485.67  476.0600  482.95   5672351  480.70
# 766    766  487.55  489.80  479.9000  485.71   5208109  485.66
# 767    767  492.00  498.96  481.4000  492.19  12198593  491.39
#
#               label  adj_close  unadjusted_volume  change  change_percent  \
# 763  January 17, 24     480.33          4894600.0   -4.17       -0.860680
# 764  January 18, 24     485.31          4054400.0    5.28        1.100000
# 765  January 19, 24     482.95          5665600.0   -2.03       -0.418570
# 766  January 22, 24     485.71          5212300.0   -1.84       -0.377400
# 767  January 23, 24     492.19         11097538.0    0.19        0.038618
#
#      change_over_time symbol  close_SMA_20
# 763         -0.008607   NFLX      484.4025
# 764          0.011000   NFLX      484.3620
# 765         -0.004186   NFLX      483.7585
# 766         -0.003774   NFLX      483.5805
# 767          0.000386   NFLX      483.6095

# %% [markdown]
# ### Analysis Q6
#
# To run the cointegration test we need to run the following command:
# 1. `obb.econometrics.cointegration(data=data, columns=data.columns)`
# 2. `obb.econometrics.cointegration(symbols=["NFLX", "ROKU", "PARA", "AMC", "WBD", "DIS"])`
# 3. `obb.econometrics.cointegration(data=data, columns=data.columns, period="2y")`
# 4. `obb.econometrics.cointegrate(data=data, columns=data.columns)`

# %%
# transpose the data so that every symbols is a column and all rows are the closing prices
data = data.reset_index().pivot(index="date", columns="symbol", values="adj_close")
data.head()
# Out:
# symbol       AMC     DIS        NFLX   PARA        ROKU        WBD
# date
# 2021-01-04  20.1  177.10  522.859985  33.65  317.899994  30.629999
# 2021-01-05  19.8  177.86  520.799988  34.01  335.179993  31.520000
# 2021-01-06  20.1  178.54  500.489990  36.96  342.950012  34.250000
# 2021-01-07  20.5  178.00  508.890015  36.88  379.290009  34.400002
# 2021-01-08  21.4  178.11  510.399994  36.83  399.130005  34.630001

# %%
coint_df = obb.econometrics.cointegration(data, columns=data.columns).to_df()
coint_df = coint_df.transpose().sort_values(by="pvalue").reset_index()
coint_df.head()
# Out:
#        index           c     gamma     alpha   adfstat    pvalue
# 0   PARA/WBD    5.566530  1.026175 -0.024695 -3.564914  0.006468
# 1   DIS/PARA   56.762347  2.542033 -0.004804 -3.548875  0.006817
# 2  PARA/ROKU   14.349225  0.077517 -0.022135 -2.950319  0.039802
# 3    AMC/DIS -169.987016  2.493936 -0.020954 -2.930127  0.041955
# 4    DIS/WBD   68.295190  2.731360 -0.005641 -2.865014  0.049570

# %% [markdown]
# ### Analysis Q7
#
# Which top 3 pairs are the most cointegrated?
# 1. DIS/PARA
# 2. PARA/ROKU
# 3. DIS/WBD
# 4. AMC/DIS
# 5. PARA/WBD

# %% [markdown]
# ### Analysis Q8
#
# To create a correlation matrix we need to run the following command:
# 1. `obb.quantitative.correlation_matrix(data=data)`
# 2. `obb.technical.correlation_matrix(data=data)`
# 3. `obb.statistics.correlation_matrix(data=data)`
# 4. `obb.econometrics.correlation_matrix(data=data)`

# %%
corr_df = obb.econometrics.correlation_matrix(data).to_df()
corr_df[["PARA", "comp_to"]].sort_values(by="PARA", ascending=False)[1:]
# Out:
#        PARA comp_to
# 5  0.961292     WBD
# 1  0.864791     DIS
# 4  0.795291    ROKU
# 0  0.461340     AMC
# 2  0.440968    NFLX

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Goals of this section:
#
# 1. Obtain the latest news for PARA and its pair trading peers
# 2. Check the differences in their Price to Performance
# 3. Concluding statement

# %% [markdown]
# ### Conclusion Q1
# To obtain the latest news for PARA and its pair trading peers, we use the following command:
#
# 1. `obb.news.latest("PARA, WBD, DIS, ROKU, AMC, NFLX")`
# 2. `obb.news.companies(["PARA", "WBD", "DIS", "ROKU", "AMC", "NFLX"])`
# 3. `obb.news.company("PARA, WBD, DIS, ROKU, AMC, NFLX")`
# 4. `obb.news.company(["PARA", "WBD", "DIS", "ROKU", "AMC", "NFLX"])`

# %%
obb.news.company("PARA, WBD, DIS, ROKU, AMC, NFLX").to_df()
# Out:
#                                                                   symbols  \
# date
# 2023-12-29 02:33:42-04:00                         CMCSA,DIS,NFLX,PARA,WBD
# 2023-12-29 15:45:30-04:00                                CMCSA,PARA,PARAA
# 2023-12-30 03:51:22-04:00                    AMZN,CMCSA,DIS,NFLX,PARA,WBD
# 2024-01-02 14:23:07-04:00                                   DIS,NFLX,PARA
# 2024-01-03 08:43:01-04:00                         CMCSA,DIS,PARA,SONY,WBD
# 2024-01-03 15:16:44-04:00  CMCSA,LGF/A,MSFT,NTDOY,PARA,PARAA,TTWO,WBD,LGF
# 2024-01-08 12:49:04-04:00           AMC,CMCSA,DIS,MAT,NFLX,PARA,PARAA,WBD
# 2024-01-08 14:29:33-04:00           CMCSA,DIS,DKNG,EA,FOX,FOXA,PARA,PARAA
# 2024-01-09 08:13:14-04:00                                            PARA
# 2024-01-10 08:34:29-04:00                                        PARA,WBD
# 2024-01-10 15:06:21-04:00                                            PARA
# 2024-01-10 18:08:43-04:00                                  PARA,PARAA,WBD
# 2024-01-11 08:45:45-04:00                                            PARA
# 2024-01-11 13:23:57-04:00                                            PARA
# 2024-01-16 17:57:05-04:00           CMCSA,DIS,DKNG,EA,FOX,FOXA,PARA,PARAA
# 2024-01-19 16:43:09-04:00                                        APO,PARA
# 2024-01-19 16:59:29-04:00                                            PARA
# 2024-01-22 13:15:11-04:00                    DIS,DKNG,FOX,FOXA,PARA,PARAA
# 2024-01-22 14:13:23-04:00                                   DIS,NFLX,PARA
# 2024-01-23 13:50:28-04:00             AMZN,DIS,GOOG,GOOGL,NFLX,PARA,PARAA
#
#                                                                        title  \
# date
# 2023-12-29 02:33:42-04:00  'Complete And Utter Panic:' Netflix Rivals Dis...
# 2023-12-30 03:51:22-04:00 2023-12-30 03:51:22-04:00
# 2024-01-02 14:23:07-04:00 2024-01-02 14:23:08-04:00
# 2024-01-03 08:43:01-04:00 2024-01-03 08:43:02-04:00
# 2024-01-03 15:16:44-04:00 2024-01-03 15:18:41-04:00
# 2024-01-08 12:49:04-04:00 2024-01-08 13:03:13-04:00
# 2024-01-08 14:29:33-04:00 2024-01-08 14:29:33-04:00
# 2024-01-09 08:13:14-04:00 2024-01-09 08:13:15-04:00
# 2024-01-10 08:34:29-04:00 2024-01-10 08:34:29-04:00
# 2024-01-10 15:06:21-04:00 2024-01-10 15:06:21-04:00
# 2024-01-10 18:08:43-04:00 2024-01-10 18:08:44-04:00
# 2024-01-11 08:45:45-04:00 2024-01-11 08:45:46-04:00
# 2024-01-11 13:23:57-04:00 2024-01-11 13:23:57-04:00
# 2024-01-16 17:57:05-04:00 2024-01-16 17:57:06-04:00
# 2024-01-19 16:43:09-04:00 2024-01-19 17:00:07-04:00
# 2024-01-19 16:59:29-04:00 2024-01-19 16:59:30-04:00
# 2024-01-22 13:15:11-04:00 2024-01-22 13:15:12-04:00
# 2024-01-22 14:13:23-04:00 2024-01-22 14:13:23-04:00
# 2024-01-23 13:50:28-04:00 2024-01-23 13:50:28-04:00

# %% [markdown]
# ### Conclusion Q2
# To obtain the price performance for PARA and its top 3 pair trading peers, we use the following command:
#
# 1. `obb.equity.price_performance(symbol=["PARA", "WBD", "DIS", "ROKU"], start_date="2021-01-01")`
# 2. `obb.equity.price.performance(symbol=["PARA", "WBD", "DIS", "ROKU"], start_date="2021-01-01")`
# 3. `obb.equity.performance(symbol=["PARA", "WBD", "DIS", "ROKU"], start_date="2021-01-01")`
# 4. `obb.equity.performance.price(symbol=["PARA", "WBD", "DIS", "ROKU"], start_date="2021-01-01")`

# %%
obb.equity.price.performance(symbol=["PARA", "WBD", "DIS", "ROKU"], start_date="2021-01-01", provider="fmp").to_df()
# Out:
#    one_day  one_week  one_month  three_month  six_month      ytd  one_year  \
# 0  -0.5091   4.82759   -8.80000     22.69058  -11.62791 -5.00000 -34.32549
# 1   0.6686   2.42954   -6.47737      4.56349  -16.41554 -9.60549 -21.22571
# 2  -1.3778   1.57062    3.02131     13.57800    8.27945  3.37339 -11.53774
# 3   2.8374   6.06273   -0.40508     48.11136   26.59338  2.21348  72.91389
#
#    three_year  five_year   ten_year           max symbol
# 0   -71.32677  -72.07023  -76.57133     -48.76404   PARA
# 1   -72.97436  -61.42020  -73.95480     -36.12121    WBD
# 2   -45.44767  -15.17865   28.94664  100827.79954    DIS
# 3   -78.67757  110.14091  287.10638     287.10638   ROKU

# %% [markdown]
# Thank you for playing this game and we hope you have learned:
# 1. Installing and setting up the OpenBB Platform and Hub
# 2. Navigating the OpenBB Platform
# 3. Installing new extensions
# 4. How to perform investment research on a company and its peers for using the pair trading strategy
# 5. Hands-on experience with the OpenBB Platform features (passing data between commands, filtering data by date, etc)
#
# For more information, please visit our documentation at https://docs.openbb.co/platform
